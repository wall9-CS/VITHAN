# %% [markdown]
# # Evaluation
# (description)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import nltk
import ast

# %%
# %cd "/content/drive/MyDrive/code/visualization/"
# Out:
# /content/drive/MyDrive/code/visualization

# %%
# dataset_name = "VTHNKG-CQ"
exp_name = "hynt"
exp_date = "20250615"
lr = 0.0004
dim = 256
test_epoch = 1050
dataset_names = [
    "VTKG-I",
    "VTHNKG-O",
    "VTHNKG-OT",
    "VTHNKG-CQ",
    "VTHNKG-CQI",
    "VTHNKG-NQ",
    "VTHNKG-NT",
    "VTHNKG-OA",
    "VTHNKG-OA_NT",
    "VTHNKG-OA_CQI"
]

# %%
entity_csvs = {}
relation_csvs = {}

for dataset_name in dataset_names:
    entity_csvs[dataset_name] = f"./{dataset_name}/{dataset_name}_{exp_name}_{exp_date}/lr_{lr}_dim_{dim}__{test_epoch}/entity_predictions.csv"
    relation_csvs[dataset_name] = f"./{dataset_name}/{dataset_name}_{exp_name}_{exp_date}/lr_{lr}_dim_{dim}__{test_epoch}/relation_predictions.csv"

# %% [markdown]
# ## Entity Predictiion

# %%
import pandas as pd

def evaluate_link_prediction_metrics(df, target_type=None):
    """
    link prediction 평가를 위한 MRR, Hit@1, Hit@k 계산 함수

    Parameters:
        df (pd.DataFrame): 평가 결과가 담긴 DataFrame (rank 열 포함)
        target_type (str or None): 'head', 'tail', 또는 None (전체 포함)
        hit_k (int): Hit rate의 k 값 (Top-k 정확도 기준)

    Returns:
        dict: MRR, Hit@1, Hit@k 값 포함 딕셔너리
    """
    if target_type == 'triplet': target = ['head', 'tail']
    if target_type == 'head': target = ['head']
    if target_type == 'tail': target = ['tail']
    if target_type == 'all': target = ['head', 'tail', 'value']
    try:
        target_df = df[df['type'].isin(target)]
    except:
        target_df = df.copy()

    if target_df.empty:
        return "No data frame"

    mrr = (1 / target_df['rank']).mean()
    hit1 = (target_df['rank'] == 1).mean()
    hit3 = (target_df['rank'] <= 3).mean()
    hit10 = (target_df['rank'] <= 10).mean()

    return {
        'MRR': float(round(mrr, 4)),
        'Hit@1': float(round(hit1, 4)),
        'Hit@3': float(round(hit3, 4)),
        'Hit@10': float(round(hit10, 4)),
        'Samples': len(target_df)
    }

# %%
import pandas as pd

def evaluate_relation_prediction_metrics(df, target_type=None):
    if target_type == 'triplet': target = ['relation']
    if target_type == 'qualifier': target = ['qualifier']
    if target_type == 'all': target = ['relation', 'qualifier']
    try:
        target_df = df[df['type'].isin(target)]
    except:
        target_df = df.copy()

    if target_df.empty:
        return "No data frame"

    mrr = (1 / target_df['rank']).mean()
    hit1 = (target_df['rank'] == 1).mean()
    hit3 = (target_df['rank'] <= 3).mean()
    hit10 = (target_df['rank'] <= 10).mean()

    return {
        'MRR': float(round(mrr, 4)),
        'Hit@1': float(round(hit1, 4)),
        'Hit@3': float(round(hit3, 4)),
        'Hit@10': float(round(hit10, 4)),
        'Samples': len(target_df)
    }

# %%
def top1_answer_distribution(df):
    top1 = nltk.FreqDist(df['top1'].to_list())
    return (top1.most_common(5), len(top1))

def top5_answer_distribution(df):
    top5 = df['top5'].to_list()
    top5 = [item for sublist in top5 for item in ast.literal_eval(sublist)]
    top5 = nltk.FreqDist(top5)
    return (top5.most_common(5), len(top5))

def num_test(df):
    return len(df)

def top5_correct_rate(df):
    top5 = [ast.literal_eval(sublist) for sublist in df['top5'].to_list()]
    gt = df['gt'].to_list()
    correct = []

    for i in range(len(top5)):
        if gt[i] in top5[i]:
            correct.append(gt[i])

    fdist = nltk.FreqDist(correct)
    flatted_top5 = [item for sublist in top5 for item in sublist]
    fdist_top5 = nltk.FreqDist(flatted_top5)

    result = []
    for item in fdist:
        correct_count = fdist[item]
        total_top5_count = fdist_top5[item]
        accuracy = correct_count / total_top5_count
        result.append((item, round(accuracy, 4), total_top5_count))

    result.sort(key=lambda x: x[1], reverse=True)

    return result[:5]

# %%
def mean_se(df):
    return df['se'].mean()

# %%
for dataset_name in dataset_names:
    entity_csv = f"./{dataset_name}/{dataset_name}_{exp_name}_{exp_date}/lr_0.0004_dim_256_elayer_4_dlayer_4_head_8_hid_2048_drop_0.15_smoothing_0.4_batch_1024_steplr_150_1050/entity_predictions.csv"
    relation_csv = f"./{dataset_name}/{dataset_name}_{exp_name}_{exp_date}/lr_0.0004_dim_256_elayer_4_dlayer_4_head_8_hid_2048_drop_0.15_smoothing_0.4_batch_1024_steplr_150_1050/relation_predictions.csv"
    numeric_csv = f"./{dataset_name}/{dataset_name}_{exp_name}_{exp_date}/lr_0.0004_dim_256_elayer_4_dlayer_4_head_8_hid_2048_drop_0.15_smoothing_0.4_batch_1024_steplr_150_1050/numeric_predictions.csv"
    df1 = pd.read_csv(entity_csv)
    df2 = pd.read_csv(relation_csv)
    try: df3 = pd.read_csv(numeric_csv)
    except: df3 = None
    print("\n")
    print("Dataset: ", dataset_name)
    print("Link Prediction")
    print("Head:", evaluate_link_prediction_metrics(df1, target_type='head'))
    print("Tail:", evaluate_link_prediction_metrics(df1, target_type='tail'))
    print("Triplet:", evaluate_link_prediction_metrics(df1, target_type='triplet'))
    print("All:", evaluate_link_prediction_metrics(df1, target_type='all'))
    print("Top1 Answer Distribution:", top1_answer_distribution(df1)[0])
    print("Top1 Answer Diversity:", top1_answer_distribution(df1)[1])
    print("Top5 Answer Distribution:", top5_answer_distribution(df1)[0])
    print("Top5 Answer Diversity:", top5_answer_distribution(df1)[1])
    print("Top5 Correct Rate:", top5_correct_rate(df1))
    print("Number of Test:", num_test(df1))
    print("\n")
    print("Relation Prediction")
    print("Qualifier:", evaluate_relation_prediction_metrics(df2, target_type='qualifier'))
    print("Triplet:", evaluate_relation_prediction_metrics(df2, target_type='triplet'))
    print("All:", evaluate_relation_prediction_metrics(df2, target_type='all'))
    print("Top1 Answer Distribution:", top1_answer_distribution(df2)[0])
    print("Top1 Answer Diversity:", top1_answer_distribution(df2)[1])
    print("Top5 Answer Distribution:", top5_answer_distribution(df2)[0])
    print("Top5 Answer Diversity:", top5_answer_distribution(df2)[1])
    print("Top5 Correct Rate:", top5_correct_rate(df2))
    print("Number of Test:", num_test(df2))
    print("\n")
    if df3 is not None:
      print("Numeric Prediction")
      print("Mean SE:", mean_se(df3))
    print("\n")

    print("-------------------------------------------------------------------")
# Out:
# Dataset:  VTKG-I
# Link Prediction
# Head: {'MRR': 0.5836, 'Hit@1': 0.5154, 'Hit@3': 0.6231, 'Hit@10': 0.6769, 'Samples': 130}
# Tail: {'MRR': 0.1857, 'Hit@1': 0.1154, 'Hit@3': 0.2077, 'Hit@10': 0.2923, 'Samples': 130}
# Triplet: {'MRR': 0.3847, 'Hit@1': 0.3154, 'Hit@3': 0.4154, 'Hit@10': 0.4846, 'Samples': 260}
# All: {'MRR': 0.3847, 'Hit@1': 0.3154, 'Hit@3': 0.4154, 'Hit@10': 0.4846, 'Samples': 260}
# Top1 Answer Distribution: [('person.n.01', 62), ('surfboard.n.01', 9), ('pillow.n.01', 8), ('pizza.n.01', 6), ('street.n.01', 6)]
# Top1 Answer Diversity: 85
# Top5 Answer Distribution: [('person.n.01', 85), ('counter.n.01', 50), ('engine.n.01', 47), ('pizza.n.01', 41), ('dog.n.01', 29)]
# Top5 Answer Diversity: 158
# Top5 Correct Rate: [('person.n.01', 0.7529, 85), ('plate.n.04', 0.5, 2), ('sky.n.01', 0.1429, 7), ('bag.n.06', 0.0909, 11), ('baggage.n.01', 0.0909, 11)]
# Number of Test: 260
#
#
# Relation Prediction
# Qualifier: No data frame
# Triplet: {'MRR': 0.2739, 'Hit@1': 0.2, 'Hit@3': 0.2846, 'Hit@10': 0.4308, 'Samples': 130}
# All: {'MRR': 0.2739, 'Hit@1': 0.2, 'Hit@3': 0.2846, 'Hit@10': 0.4308, 'Samples': 130}
# Top1 Answer Distribution: [('have.v.01', 15), ('wear.v.01', 9), ('transport.v.02', 6), ('cover.v.01', 6), ('sit.v.01', 5)]
# Top1 Answer Diversity: 55
# Top5 Answer Distribution: [('have.v.01', 34), ('transport.v.02', 19), ('sit.v.01', 19), ('look.v.01', 19), ('wear.v.01', 18)]
# Top5 Answer Diversity: 152
# Top5 Correct Rate: [('have.v.01', 0.3235, 34), ('wear.v.01', 0.1667, 18), ('attach_to.v.01', 0.1667, 6), ('pull.v.01', 0.1429, 7), ('sit.v.01', 0.1053, 19)]
# Number of Test: 130
#
#
#
#
# -------------------------------------------------------------------
#
#
# Dataset:  VTHNKG-O
# Link Prediction
# Head: {'MRR': 0.6559, 'Hit@1': 0.5985, 'Hit@3': 0.6667, 'Hit@10': 0.8182, 'Samples': 132}
# Tail: {'MRR': 0.5581, 'Hit@1': 0.4773, 'Hit@3': 0.5833, 'Hit@10': 0.7273, 'Samples': 132}
# Triplet: {'MRR': 0.607, 'Hit@1': 0.5379, 'Hit@3': 0.625, 'Hit@10': 0.7727, 'Samples': 264}
# All: {'MRR': 0.5247, 'Hit@1': 0.4373, 'Hit@3': 0.569, 'Hit@10': 0.6991, 'Samples': 638}
# Top1 Answer Distribution: [('person.n.01', 106), ('person.n.02', 63), ('truck.n.01', 21), ('backpack.n.01', 17), ('coat.n.03', 15)]
# Top1 Answer Diversity: 106
# Top5 Answer Distribution: [('person.n.01', 161), ('person.n.02', 120), ('truck.n.01', 68), ('elephant.n.01', 65), ('bicycle.n.01', 62)]
# Top5 Answer Diversity: 173
# Top5 Correct Rate: [('refrigerator.n.01', 0.8, 5), ('cake.n.01', 0.6667, 3), ('person.n.01', 0.5155, 161), ('hotdog.n.02', 0.4444, 18), ('fireplug.n.01', 0.3333, 3)]
# Number of Test: 638
#
#
# Relation Prediction
# Qualifier: {'MRR': 0.4409, 'Hit@1': 0.3316, 'Hit@3': 0.5134, 'Hit@10': 0.6337, 'Samples': 374}
# Triplet: {'MRR': 0.5969, 'Hit@1': 0.5455, 'Hit@3': 0.6288, 'Hit@10': 0.6591, 'Samples': 132}
# All: {'MRR': 0.4816, 'Hit@1': 0.3874, 'Hit@3': 0.5435, 'Hit@10': 0.6403, 'Samples': 506}
# Top1 Answer Distribution: [('have.v.01', 55), ('have.v.02', 33), ('ride.v.02', 30), ('hold.v.10', 26), ('own.v.01', 24)]
# Top1 Answer Diversity: 92
# Top5 Answer Distribution: [('have.v.01', 84), ('own.v.01', 77), ('have.v.02', 76), ('hold.v.10', 75), ('carry.v.02', 69)]
# Top5 Answer Diversity: 195
# Top5 Correct Rate: [('have.v.01', 0.4405, 84), ('wear.v.02', 0.36, 25), ('taller_than', 0.3571, 14), ('have.v.02', 0.3289, 76), ('tall.a.01', 0.3, 20)]
# Number of Test: 506
#
#
#
#
# -------------------------------------------------------------------
#
#
# Dataset:  VTHNKG-OT
# Link Prediction
# Head: {'MRR': 0.4859, 'Hit@1': 0.4321, 'Hit@3': 0.5, 'Hit@10': 0.5864, 'Samples': 162}
# Tail: {'MRR': 0.1464, 'Hit@1': 0.0853, 'Hit@3': 0.1473, 'Hit@10': 0.2791, 'Samples': 129}
# Triplet: {'MRR': 0.3354, 'Hit@1': 0.2784, 'Hit@3': 0.3436, 'Hit@10': 0.4502, 'Samples': 291}
# All: {'MRR': 0.3354, 'Hit@1': 0.2784, 'Hit@3': 0.3436, 'Hit@10': 0.4502, 'Samples': 291}
# Top1 Answer Distribution: [('person.n.01', 66), ('building.n.01', 11), ('grass.n.01', 10), ('dog.n.01', 10), ('car.n.01', 8)]
# Top1 Answer Diversity: 84
# Top5 Answer Distribution: [('person.n.01', 97), ('bed.n.01', 45), ('motorcycle.n.01', 40), ('toilet.n.01', 38), ('dog.n.01', 37)]
# Top5 Answer Diversity: 152
# Top5 Correct Rate: [('person.n.01', 0.701, 97), ('laptop.n.01', 0.125, 8), ('road.n.01', 0.1111, 9), ('giraffe.n.01', 0.0833, 12), ('plant.n.02', 0.0714, 14)]
# Number of Test: 291
#
#
# Relation Prediction
# Qualifier: No data frame
# Triplet: {'MRR': 0.2533, 'Hit@1': 0.1296, 'Hit@3': 0.3272, 'Hit@10': 0.4259, 'Samples': 162}
# All: {'MRR': 0.2533, 'Hit@1': 0.1296, 'Hit@3': 0.3272, 'Hit@10': 0.4259, 'Samples': 162}
# Top1 Answer Distribution: [('have.v.01', 18), ('lengthAverage', 16), ('weightAverage', 15), ('eat.v.02', 5), ('hold.v.11', 5)]
# Top1 Answer Diversity: 61
# Top5 Answer Distribution: [('have.v.01', 39), ('lengthAverage', 35), ('wear.v.01', 31), ('weightAverage', 25), ('touch.v.01', 23)]
# Top5 Answer Diversity: 154
# Top5 Correct Rate: [('fly.v.01', 0.5, 2), ('have.v.01', 0.2821, 39), ('against', 0.1667, 6), ('lengthAverage', 0.0857, 35), ('weightAverage', 0.08, 25)]
# Number of Test: 162
#
#
# Numeric Prediction
# Mean SE: 0.026301040662873993
#
#
# -------------------------------------------------------------------
#
#
# Dataset:  VTHNKG-CQ
# Link Prediction
# Head: {'MRR': 0.5945, 'Hit@1': 0.5, 'Hit@3': 0.6515, 'Hit@10': 0.7652, 'Samples': 132}
# Tail: {'MRR': 0.1225, 'Hit@1': 0.0606, 'Hit@3': 0.1136, 'Hit@10': 0.2955, 'Samples': 132}
# Triplet: {'MRR': 0.3585, 'Hit@1': 0.2803, 'Hit@3': 0.3826, 'Hit@10': 0.5303, 'Samples': 264}
# All: {'MRR': 0.294, 'Hit@1': 0.1803, 'Hit@3': 0.3417, 'Hit@10': 0.5219, 'Samples': 638}
# Top1 Answer Distribution: [('person.n.01', 105), ('person.n.02', 41), ('table.n.01', 41), ('laptop.n.01', 28), ('horse.n.01', 26)]
# Top1 Answer Diversity: 94
# Top5 Answer Distribution: [('person.n.01', 210), ('person.n.02', 187), ('laptop.n.01', 128), ('dog.n.01', 107), ('backpack.n.01', 104)]
# Top5 Answer Diversity: 158
# Top5 Correct Rate: [('wine.n.01', 1.0, 1), ('book.n.01', 0.5, 2), ('person.n.01', 0.4048, 210), ('hotdog.n.02', 0.2857, 7), ('knife.n.01', 0.25, 8)]
# Number of Test: 638
#
#
# Relation Prediction
# Qualifier: {'MRR': 0.4939, 'Hit@1': 0.3828, 'Hit@3': 0.5511, 'Hit@10': 0.7174, 'Samples': 499}
# Triplet: {'MRR': 0.2717, 'Hit@1': 0.197, 'Hit@3': 0.303, 'Hit@10': 0.4394, 'Samples': 132}
# All: {'MRR': 0.4474, 'Hit@1': 0.3439, 'Hit@3': 0.4992, 'Hit@10': 0.6593, 'Samples': 631}
# Top1 Answer Distribution: [('legAmount', 89), ('have.v.01', 57), ('have.v.02', 55), ('hold.v.10', 44), ('sit.v.01', 38)]
# Top1 Answer Diversity: 83
# Top5 Answer Distribution: [('have.v.02', 166), ('hold.v.10', 154), ('have.v.01', 146), ('weightAverage', 125), ('lengthAverage', 125)]
# Top5 Answer Diversity: 167
# Top5 Correct Rate: [('legAmount', 0.8053, 113), ('wear.v.02', 0.3462, 26), ('have.v.02', 0.241, 166), ('launch.v.02', 0.2, 5), ('ride.v.02', 0.1961, 51)]
# Number of Test: 631
#
#
# Numeric Prediction
# Mean SE: 0.04960737070807953
#
#
# -------------------------------------------------------------------
#
#
# Dataset:  VTHNKG-CQI
# Link Prediction
# Head: {'MRR': 0.7335, 'Hit@1': 0.6667, 'Hit@3': 0.7727, 'Hit@10': 0.8636, 'Samples': 132}
# Tail: {'MRR': 0.1972, 'Hit@1': 0.1136, 'Hit@3': 0.2045, 'Hit@10': 0.3788, 'Samples': 132}
# Triplet: {'MRR': 0.4654, 'Hit@1': 0.3902, 'Hit@3': 0.4886, 'Hit@10': 0.6212, 'Samples': 264}
# All: {'MRR': 0.4117, 'Hit@1': 0.2947, 'Hit@3': 0.4592, 'Hit@10': 0.6395, 'Samples': 638}
# Top1 Answer Distribution: [('person.n.01', 126), ('person.n.02', 46), ('bicycle.n.01', 24), ('backpack.n.01', 19), ('laptop.n.01', 18)]
# Top1 Answer Diversity: 96
# Top5 Answer Distribution: [('person.n.01', 219), ('person.n.02', 139), ('dog.n.01', 110), ('truck.n.01', 79), ('coat.n.03', 70)]
# Top5 Answer Diversity: 155
# Top5 Correct Rate: [('wine.n.01', 1.0, 1), ('person.n.01', 0.4292, 219), ('hotdog.n.02', 0.3333, 12), ('doughnut.n.02', 0.25, 4), ('knife.n.01', 0.2, 10)]
# Number of Test: 638
#
#
# Relation Prediction
# Qualifier: {'MRR': 0.721, 'Hit@1': 0.6626, 'Hit@3': 0.7494, 'Hit@10': 0.8411, 'Samples': 818}
# Triplet: {'MRR': 0.3718, 'Hit@1': 0.2879, 'Hit@3': 0.3788, 'Hit@10': 0.5455, 'Samples': 132}
# All: {'MRR': 0.6725, 'Hit@1': 0.6105, 'Hit@3': 0.6979, 'Hit@10': 0.8, 'Samples': 950}
# Top1 Answer Distribution: [('lengthAverage', 125), ('weightAverage', 124), ('legAmount', 102), ('lifespan', 94), ('have.v.01', 63)]
# Top1 Answer Diversity: 92
# Top5 Answer Distribution: [('lifespan', 224), ('legAmount', 216), ('have.v.02', 177), ('lengthAverage', 163), ('weightAverage', 153)]
# Top5 Answer Diversity: 166
# Top5 Correct Rate: [('weightAverage', 0.8039, 153), ('lengthAverage', 0.7669, 163), ('legAmount', 0.4722, 216), ('lifespan', 0.4196, 224), ('read.v.01', 0.3333, 3)]
# Number of Test: 950
#
#
# Numeric Prediction
# Mean SE: 0.010140239951968244
#
#
# -------------------------------------------------------------------
#
#
# Dataset:  VTHNKG-NQ
# Link Prediction
# Head: {'MRR': 0.8184, 'Hit@1': 0.7803, 'Hit@3': 0.8333, 'Hit@10': 0.9015, 'Samples': 132}
# Tail: {'MRR': 0.1644, 'Hit@1': 0.0909, 'Hit@3': 0.1667, 'Hit@10': 0.3106, 'Samples': 132}
# Triplet: {'MRR': 0.4914, 'Hit@1': 0.4356, 'Hit@3': 0.5, 'Hit@10': 0.6061, 'Samples': 264}
# All: {'MRR': 0.4914, 'Hit@1': 0.4356, 'Hit@3': 0.5, 'Hit@10': 0.6061, 'Samples': 264}
# Top1 Answer Distribution: [('person.n.01', 85), ('dog.n.01', 9), ('bicycle.n.01', 8), ('telephone.n.01', 8), ('plant.n.02', 7)]
# Top1 Answer Diversity: 71
# Top5 Answer Distribution: [('person.n.01', 104), ('mouse.n.01', 83), ('toaster.n.02', 58), ('horse.n.01', 42), ('cone.n.01', 39)]
# Top5 Answer Diversity: 141
# Top5 Correct Rate: [('person.n.01', 0.8173, 104), ('giraffe.n.01', 0.3, 10), ('vase.n.01', 0.2857, 7), ('dog.n.01', 0.2353, 17), ('motorcycle.n.01', 0.2308, 13)]
# Number of Test: 264
#
#
# Relation Prediction
# Qualifier: {'MRR': 0.9843, 'Hit@1': 0.9746, 'Hit@3': 0.9915, 'Hit@10': 1.0, 'Samples': 118}
# Triplet: {'MRR': 0.2104, 'Hit@1': 0.1212, 'Hit@3': 0.2348, 'Hit@10': 0.3939, 'Samples': 132}
# All: {'MRR': 0.5756, 'Hit@1': 0.524, 'Hit@3': 0.592, 'Hit@10': 0.68, 'Samples': 250}
# Top1 Answer Distribution: [('lifespan', 85), ('have.v.01', 13), ('weightAverage', 12), ('lengthAverage', 12), ('legAmount', 10)]
# Top1 Answer Diversity: 61
# Top5 Answer Distribution: [('lifespan', 98), ('pull.v.01', 96), ('jump.v.01', 63), ('ride.v.10', 57), ('hop_on.v.01', 56)]
# Top5 Answer Diversity: 143
# Top5 Correct Rate: [('lifespan', 0.8469, 98), ('legAmount', 0.7692, 13), ('lengthAverage', 0.6, 20), ('weightAverage', 0.4583, 24), ('fly.v.01', 0.3333, 3)]
# Number of Test: 250
#
#
# Numeric Prediction
# Mean SE: 0.0013042173818881206
#
#
# -------------------------------------------------------------------
#
#
# Dataset:  VTHNKG-NT
# Link Prediction
# Head: {'MRR': 0.5547, 'Hit@1': 0.472, 'Hit@3': 0.6025, 'Hit@10': 0.7081, 'Samples': 161}
# Tail: {'MRR': 0.5795, 'Hit@1': 0.5038, 'Hit@3': 0.6316, 'Hit@10': 0.6917, 'Samples': 133}
# Triplet: {'MRR': 0.5659, 'Hit@1': 0.4864, 'Hit@3': 0.6156, 'Hit@10': 0.7007, 'Samples': 294}
# All: {'MRR': 0.5246, 'Hit@1': 0.4343, 'Hit@3': 0.5806, 'Hit@10': 0.6821, 'Samples': 670}
# Top1 Answer Distribution: [('person.n.01', 99), ('person.n.02', 63), ('truck.n.01', 30), ('motorcycle.n.01', 17), ('laptop.n.01', 15)]
# Top1 Answer Diversity: 112
# Top5 Answer Distribution: [('person.n.01', 146), ('person.n.02', 109), ('motorcycle.n.01', 78), ('truck.n.01', 64), ('elephant.n.01', 59)]
# Top5 Answer Diversity: 177
# Top5 Correct Rate: [('person.n.01', 0.5685, 146), ('can.n.01', 0.5, 6), ('hotdog.n.02', 0.4375, 16), ('knife.n.01', 0.3571, 14), ('doughnut.n.02', 0.3333, 12)]
# Number of Test: 670
#
#
# Relation Prediction
# Qualifier: {'MRR': 0.4556, 'Hit@1': 0.3484, 'Hit@3': 0.5266, 'Hit@10': 0.6436, 'Samples': 376}
# Triplet: {'MRR': 0.6234, 'Hit@1': 0.559, 'Hit@3': 0.6708, 'Hit@10': 0.7453, 'Samples': 161}
# All: {'MRR': 0.5059, 'Hit@1': 0.4115, 'Hit@3': 0.5698, 'Hit@10': 0.6741, 'Samples': 537}
# Top1 Answer Distribution: [('have.v.01', 45), ('hold.v.10', 33), ('have.v.02', 32), ('ride.v.02', 27), ('own.v.01', 25)]
# Top1 Answer Diversity: 95
# Top5 Answer Distribution: [('have.v.01', 95), ('own.v.01', 92), ('hold.v.10', 91), ('have.v.02', 74), ('hold.v.11', 62)]
# Top5 Answer Diversity: 189
# Top5 Correct Rate: [('weightAverage', 0.5294, 34), ('have.v.01', 0.4, 95), ('have.v.02', 0.3919, 74), ('pull.v.04', 0.3125, 16), ('jump.v.01', 0.2857, 7)]
# Number of Test: 537
#
#
# Numeric Prediction
# Mean SE: 0.027448477689087446
#
#
# -------------------------------------------------------------------
#
#
# Dataset:  VTHNKG-OA
# Link Prediction
# Head: {'MRR': 0.7016, 'Hit@1': 0.6439, 'Hit@3': 0.7197, 'Hit@10': 0.803, 'Samples': 132}
# Tail: {'MRR': 0.2896, 'Hit@1': 0.197, 'Hit@3': 0.3485, 'Hit@10': 0.4394, 'Samples': 132}
# Triplet: {'MRR': 0.4956, 'Hit@1': 0.4205, 'Hit@3': 0.5341, 'Hit@10': 0.6212, 'Samples': 264}
# All: {'MRR': 0.4899, 'Hit@1': 0.3946, 'Hit@3': 0.5464, 'Hit@10': 0.6476, 'Samples': 593}
# Top1 Answer Distribution: [('person.n.01', 113), ('bag.n.06', 39), ('bench.n.01', 21), ('baggage.n.01', 20), ('road.n.01', 19)]
# Top1 Answer Diversity: 106
# Top5 Answer Distribution: [('person.n.01', 147), ('baggage.n.01', 97), ('bag.n.06', 73), ('dog.n.01', 58), ('hand.n.01', 55)]
# Top5 Answer Diversity: 169
# Top5 Correct Rate: [('person.n.01', 0.5442, 147), ('surfboard.n.01', 0.4375, 16), ('skateboard.n.01', 0.4118, 17), ('backpack.n.01', 0.2727, 55), ('bench.n.01', 0.2727, 55)]
# Number of Test: 593
#
#
# Relation Prediction
# Qualifier: {'MRR': 0.5235, 'Hit@1': 0.4164, 'Hit@3': 0.5927, 'Hit@10': 0.6991, 'Samples': 329}
# Triplet: {'MRR': 0.2503, 'Hit@1': 0.1667, 'Hit@3': 0.2879, 'Hit@10': 0.3864, 'Samples': 132}
# All: {'MRR': 0.4453, 'Hit@1': 0.3449, 'Hit@3': 0.5054, 'Hit@10': 0.6095, 'Samples': 461}
# Top1 Answer Distribution: [('contain.v.05', 45), ('carry.v.02', 36), ('hold.v.02', 36), ('rest_on', 27), ('sit_on', 25)]
# Top1 Answer Diversity: 88
# Top5 Answer Distribution: [('contain.v.05', 102), ('hold.v.02', 73), ('rest_on', 69), ('use.v.01', 68), ('carry.v.02', 67)]
# Top5 Answer Diversity: 182
# Top5 Correct Rate: [('have.v.01', 0.3846, 39), ('wear.v.01', 0.3684, 38), ('carry.v.02', 0.3433, 67), ('park.v.01', 0.3333, 3), ('skate.v.01', 0.2857, 7)]
# Number of Test: 461
#
#
#
#
# -------------------------------------------------------------------
#
#
# Dataset:  VTHNKG-OA_NT
# Link Prediction
# Head: {'MRR': 0.5434, 'Hit@1': 0.497, 'Hit@3': 0.5455, 'Hit@10': 0.6485, 'Samples': 165}
# Tail: {'MRR': 0.2986, 'Hit@1': 0.2121, 'Hit@3': 0.3409, 'Hit@10': 0.4924, 'Samples': 132}
# Triplet: {'MRR': 0.4346, 'Hit@1': 0.3704, 'Hit@3': 0.4545, 'Hit@10': 0.5791, 'Samples': 297}
# All: {'MRR': 0.4477, 'Hit@1': 0.3546, 'Hit@3': 0.4952, 'Hit@10': 0.6278, 'Samples': 626}
# Top1 Answer Distribution: [('person.n.01', 110), ('bag.n.06', 33), ('backpack.n.01', 25), ('baggage.n.01', 19), ('bench.n.01', 18)]
# Top1 Answer Diversity: 111
# Top5 Answer Distribution: [('person.n.01', 140), ('bag.n.06', 93), ('motorcycle.n.01', 60), ('backpack.n.01', 59), ('bird.n.01', 57)]
# Top5 Answer Diversity: 171
# Top5 Correct Rate: [('person.n.01', 0.5714, 140), ('doughnut.n.02', 0.5, 4), ('surfboard.n.01', 0.3684, 19), ('helmet.n.01', 0.3333, 21), ('bed.n.01', 0.2941, 17)]
# Number of Test: 626
#
#
# Relation Prediction
# Qualifier: {'MRR': 0.5016, 'Hit@1': 0.3891, 'Hit@3': 0.5684, 'Hit@10': 0.7052, 'Samples': 329}
# Triplet: {'MRR': 0.2938, 'Hit@1': 0.1455, 'Hit@3': 0.4121, 'Hit@10': 0.503, 'Samples': 165}
# All: {'MRR': 0.4322, 'Hit@1': 0.3077, 'Hit@3': 0.5162, 'Hit@10': 0.6377, 'Samples': 494}
# Top1 Answer Distribution: [('contain.v.05', 50), ('carry.v.02', 34), ('rest_on', 28), ('use.v.01', 28), ('hold.v.02', 27)]
# Top1 Answer Diversity: 96
# Top5 Answer Distribution: [('contain.v.05', 97), ('use.v.01', 84), ('rest_on', 79), ('carry.v.02', 79), ('hold.v.02', 65)]
# Top5 Answer Diversity: 183
# Top5 Correct Rate: [('play.v.01', 0.3125, 16), ('wear.v.01', 0.2857, 56), ('carry.v.02', 0.2785, 79), ('sit_on', 0.2586, 58), ('skate.v.01', 0.25, 4)]
# Number of Test: 494
#
#
# Numeric Prediction
# Mean SE: 0.0734034287663965
#
#
# -------------------------------------------------------------------
#
#
# Dataset:  VTHNKG-OA_CQI
# Link Prediction
# Head: {'MRR': 0.5967, 'Hit@1': 0.5303, 'Hit@3': 0.6136, 'Hit@10': 0.7273, 'Samples': 132}
# Tail: {'MRR': 0.1205, 'Hit@1': 0.0682, 'Hit@3': 0.1061, 'Hit@10': 0.2197, 'Samples': 132}
# Triplet: {'MRR': 0.3586, 'Hit@1': 0.2992, 'Hit@3': 0.3598, 'Hit@10': 0.4735, 'Samples': 264}
# All: {'MRR': 0.371, 'Hit@1': 0.2664, 'Hit@3': 0.4148, 'Hit@10': 0.5767, 'Samples': 593}
# Top1 Answer Distribution: [('person.n.01', 104), ('hand.n.01', 33), ('baggage.n.01', 31), ('bench.n.01', 27), ('backpack.n.01', 25)]
# Top1 Answer Diversity: 93
# Top5 Answer Distribution: [('person.n.01', 237), ('hand.n.01', 111), ('bag.n.06', 106), ('dog.n.01', 97), ('baggage.n.01', 96)]
# Top5 Answer Diversity: 155
# Top5 Correct Rate: [('plant.n.02', 0.5, 4), ('helmet.n.01', 0.4, 15), ('person.n.01', 0.346, 237), ('beer.n.01', 0.3333, 6), ('backpack.n.01', 0.2909, 55)]
# Number of Test: 593
#
#
# Relation Prediction
# Qualifier: {'MRR': 0.7472, 'Hit@1': 0.6598, 'Hit@3': 0.8176, 'Hit@10': 0.9056, 'Samples': 773}
# Triplet: {'MRR': 0.2002, 'Hit@1': 0.1136, 'Hit@3': 0.1894, 'Hit@10': 0.3939, 'Samples': 132}
# All: {'MRR': 0.6674, 'Hit@1': 0.5801, 'Hit@3': 0.726, 'Hit@10': 0.8309, 'Samples': 905}
# Top1 Answer Distribution: [('weightAverage', 138), ('lengthAverage', 121), ('legAmount', 100), ('lifespan', 85), ('contain.v.05', 59)]
# Top1 Answer Diversity: 81
# Top5 Answer Distribution: [('lengthAverage', 445), ('weightAverage', 373), ('legAmount', 330), ('lifespan', 326), ('rest_on', 242)]
# Top5 Answer Diversity: 149
# Top5 Correct Rate: [('play.v.01', 0.4167, 12), ('carry.v.02', 0.4, 80), ('wear.v.01', 0.3571, 42), ('drink.v.01', 0.3333, 6), ('weightAverage', 0.3298, 373)]
# Number of Test: 905
#
#
# Numeric Prediction
# Mean SE: 0.044881912610341
#
#
# -------------------------------------------------------------------
